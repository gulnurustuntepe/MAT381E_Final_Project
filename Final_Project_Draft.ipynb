# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('features_3_sec.csv')
data
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
# ...

# %%
data = pd.read_csv('features_30_sec.csv')
data
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
blues=data.head(100)
classical=data[100:200]
country=data[200:300]
disco=data[300:400]
hiphop=data[400:500]
jazz=data[500:600]
metal=data[600:700]
pop=data[700:800]
reggae=data[800:900]
rock=data[900:1000]

# %%
classical
# Out:
#                 filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 100  classical.00000.wav  661794          0.252392         0.084153  0.036245
# 101  classical.00001.wav  661794          0.214995         0.085010  0.030625
# 102  classical.00002.wav  661794          0.277958         0.083759  0.043860
# 103  classical.00003.wav  661794          0.234229         0.083451  0.029442
# 104  classical.00004.wav  661794          0.221574         0.085000  0.042316
# ..                   ...     ...               ...              ...       ...
# 195  classical.00095.wav  661794          0.227693         0.088256  0.013564
# 196  classical.00096.wav  661794          0.293052         0.082874  0.056987
# 197  classical.00097.wav  661794          0.222265         0.083254  0.036720
# 198  classical.00098.wav  661794          0.289919         0.088790  0.029094
# 199  classical.00099.wav  661794          0.333908         0.078685  0.010506
#
# ...

# %%
def getdouble(genre):
    return classical.reset_index(drop='True').compare(genre.reset_index(drop='True'))

# %% [markdown]
# Function for getting Dataframes with two genres in order to compare them later on.

# %%
getdouble(blues)
# Out:
#                filename                  length       chroma_stft_mean  \
#                    self            other   self other             self
# 0   classical.00000.wav  blues.00000.wav    NaN   NaN         0.252392
# 1   classical.00001.wav  blues.00001.wav    NaN   NaN         0.214995
# 2   classical.00002.wav  blues.00002.wav    NaN   NaN         0.277958
# 3   classical.00003.wav  blues.00003.wav    NaN   NaN         0.234229
# 4   classical.00004.wav  blues.00004.wav    NaN   NaN         0.221574
# ..                  ...              ...    ...   ...              ...
# 95  classical.00095.wav  blues.00095.wav    NaN   NaN         0.227693
# 96  classical.00096.wav  blues.00096.wav    NaN   NaN         0.293052
# 97  classical.00097.wav  blues.00097.wav    NaN   NaN         0.222265
# 98  classical.00098.wav  blues.00098.wav    NaN   NaN         0.289919
# 99  classical.00099.wav  blues.00099.wav    NaN   NaN         0.333908
#
# ...

# %%
getdouble(blues).keys()
# Out:
# MultiIndex([(        'filename',  'self'),
#             (        'filename', 'other'),
#             (          'length',  'self'),
#             (          'length', 'other'),
#             ('chroma_stft_mean',  'self'),
#             ('chroma_stft_mean', 'other'),
#             ( 'chroma_stft_var',  'self'),
#             ( 'chroma_stft_var', 'other'),
#             (        'rms_mean',  'self'),
#             (        'rms_mean', 'other'),
#             ...
#             (     'mfcc19_mean',  'self'),
#             (     'mfcc19_mean', 'other'),
#             (      'mfcc19_var',  'self'),
#             (      'mfcc19_var', 'other'),
#             (     'mfcc20_mean',  'self'),
#             (     'mfcc20_mean', 'other'),
#             (      'mfcc20_var',  'self'),
#             (      'mfcc20_var', 'other'),
#             (           'label',  'self'),
#             (           'label', 'other')],
#            length=120)

# %%
def comparediff(genre):
    return {i:
           [getdouble(genre)[i, 'self'].sub(getdouble(genre)[i, 'other'])]for i in classical.keys()}

# %%
comparediff(blues)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1t/p50myd5x19nf39jzsbtbcg_00000gp/T/ipykernel_786/1410603084.py in <module>
# ----> 1 comparediff(blues)
#
# /var/folders/1t/p50myd5x19nf39jzsbtbcg_00000gp/T/ipykernel_786/966295480.py in comparediff(genre)
#       1 def comparediff(genre):
# ----> 2     return {i:
#       3            [getdouble(genre)[i, 'self'].sub(getdouble(genre)[i, 'other'])]for i in classical.keys()}
#
# /var/folders/1t/p50myd5x19nf39jzsbtbcg_00000gp/T/ipykernel_786/966295480.py in <dictcomp>(.0)
#       1 def comparediff(genre):
#       2     return {i:
# ----> 3            [getdouble(genre)[i, 'self'].sub(getdouble(genre)[i, 'other'])]for i in classical.keys()}
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     182
# ...

# %%
classBluesdata=({'chroma_stft_mean':
                [getdouble(blues)['chroma_stft_mean', 'self'].sub(getdouble(blues)['chroma_stft_mean', 'other'])],
                 'chroma_stft_var':
                [getdouble(blues)['chroma_stft_var',  'self'].sub(getdouble(blues)['chroma_stft_var', 'other'])],
                'rms_mean':
                 [getdouble(blues)['rms_mean',  'self'].sub(getdouble(blues)['rms_mean',  'other'])]
                })
classBluesdata
# Out:
# {'chroma_stft_mean': [0    -0.097696
#   1    -0.125919
#   2    -0.085679
#   3    -0.170555
#   4    -0.086952
#           ...
#   95   -0.142251
#   96    0.032527
#   97   -0.152797
#   98   -0.153046
#   99   -0.036306
#   Length: 100, dtype: float64],
#  'chroma_stft_var': [0    -0.004603
#   1    -0.009971
#   2    -0.001516
#   3    -0.010548
#   4    -0.002841
#           ...
#   95   -0.003035
#   96   -0.008939
#   97   -0.010602
#   98    0.010473
#   99   -0.006457
#   Length: 100, dtype: float64],
#  'rms_mean': [0    -0.093983
#   1    -0.065323
#   2    -0.131711
#   3    -0.111651
#   4    -0.049212
#           ...
#   95   -0.173529
#   96    0.005587
#   97   -0.161609
#   98   -0.096362
#   99   -0.094506
#   Length: 100, dtype: float64]}

# %%
pd.DataFrame(classBluesdata)
# Out:
#                                     chroma_stft_mean  \
# 0  0    -0.097696
# 1    -0.125919
# 2    -0.085679
# 3...
#
#                                      chroma_stft_var  \
# 0  0    -0.004603
# 1    -0.009971
# 2    -0.001516
# 3...
#
#                                             rms_mean
# 0  0    -0.093983
# 1    -0.065323
# 2    -0.131711
# 3...

# %%
def comparediff(genre):
        return {'chroma_stft_mean':
                [getdouble(genre)['chroma_stft_mean', 'self'].sub(getdouble(genre)['chroma_stft_mean', 'other'])],
                 'chroma_stft_var':
                [getdouble(genre)['chroma_stft_var',  'self'].sub(getdouble(genre)['chroma_stft_var', 'other'])],
                'rms_mean':
                 [getdouble(genre)['rms_mean',  'self'].sub(getdouble(genre)['rms_mean',  'other'])],
                
                }

# %%
classVsBlues=classBlues['chroma_stft_mean', 'self'].sub(classBlues['chroma_stft_mean', 'other']).to_frame('chroma_stft_mean')

# %% [markdown]
# ### Chroma stft value
# The Chroma value of an audio basically represent the intensity of the twelve distinctive pitch classes that are used to study music. They can be employed in the differentiation of the pitch class profiles between audio signals. Chroma STFT in Fig. 5. used short-term Fourier transformation to compute Chroma features. STFT represents information about the classification of pitch and signal structure. It depicts the spike with high values (as evident from the color bar net to the graph) in low values (dark regions).
# ### RMS
# average loudness
# ### Centroid, Rolloff, bandwidth
# just some properties
# ### Harmony
# important
